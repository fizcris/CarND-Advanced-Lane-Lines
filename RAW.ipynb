# %% [markdown]
# # Advanced lane lines

# %% [markdown]
# # Finding lines

# %% [markdown]
# # Unwarp images

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-ce5a5326ec85> in <module>
#       1 unwarped_img = warp_image(warped_img, conversion= 'unwarp', hwidth = 250 ,offset = 0, height = -600, overplotLines = False )
#       2
# ----> 3 image_out = cv2.addWeighted(unwarped_img, 0.5,und_images[currentIndex] , 1, 0.0)
#       4
#       5 displayListImages([image_out],cols=1,cmap='gray',figSize=[12,4])
#
# TypeError: Expected cv::UMat for argument 'src1'
